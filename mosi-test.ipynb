# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

address = "/content/drive/MyDrive/masks/"

train_labels = os.listdir(address)

print(train_labels)
# Out:
# ['DATALABLLLLL.xlsx', '108', '102', '106', '101', '109', '100', '105', '110', '112', '113', '12', '123', '124', '121', '117', '16', '18', '122', '116', '120', '4', '28', '29', '6', '25', '26', '39', '24', '54', '20', '70', '72', '92', '94', '76', '73', '77', '71', '78', '83', '95', '96', '98']

# %%
import pandas as pd

df = pd.read_excel (r'/content/drive/MyDrive/masks/DATALABLLLLL.xlsx')

total_rows=len(df.axes[0])
total_cols=len(df.axes[1])

print(df)
print(total_rows)
print(total_cols)
# Out:
#     Name of pateient's Number of file  ...         NUMBER OF TUMOR Age
# 0                    4          15956  ...                       1  83
# 1                    6           7865  ...                       3  62
# 2                   12           5537  ...                       1  33
# 3                   16           6682  ...                       1  44
# 4                   18          13914  ...                       4  50
# 5                   20           2432  ...                       2  60
# 6                   24          15481  ...                       1  61
# 7                   25          17131  ...                       2  61
# 8                   26          10900  ...                       1  50
# 9                   28           9949  ...                       3  33
# 10                  29           9032  ...                       1  68
# 11                  39       2756162'  ...                       2  46
# ...

# %%
import cv2
import matplotlib.pyplot as plt

print(img.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 182 218 182   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  1.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'5.0.10'
# aux_file        : b''
# qform_code      : mni
# sform_code      : mni
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 90.0
# ...

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 7.6 MB/s
# ...

# %%
img1 = img.slicer[0:1]
#img1 = img[:,:,1]

# %%
img1.shape
#plt.figure()
#plt.imshow(img1)
#plt.show()
# Out:
# (1, 218, 182)

# %%
img1
#img1_new = img1.affine

# %%
plt.figure()
plt.imshow(img1_new)
plt.show()
