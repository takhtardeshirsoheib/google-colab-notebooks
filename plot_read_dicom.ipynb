# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 5.3 MB/s
# ...

# %% [markdown]
# # Read a Dataset and plot Pixel Data
#
# This example illustrates how to open a DICOM file, print some dataset
# information, and show it using matplotlib.

# %%
# authors : Guillaume Lemaitre <g.lemaitre58@gmail.com>
# license : MIT

import matplotlib.pyplot as plt
import pydicom
import pydicom.data
  
# Full path of the DICOM file is passed in base
base = r"/content/drive/MyDrive/masks/4"
pass_dicom = "4EDEMA_MASK.dcm"  # file name is 1-12.dcm
  
# enter DICOM image name for pattern
# result is a list of 1 element
filename = pydicom.data.data_manager.get_files(base, pass_dicom)[0]
  
ds = pydicom.dcmread(filename)
ds.header
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e0067fab1cab> in <module>()
#      15
#      16 ds = pydicom.dcmread(filename)
# ---> 17 ds.header
#
# /usr/local/lib/python3.7/dist-packages/pydicom/dataset.py in __getattr__(self, name)
#     834             return {}
#     835         # Try the base class attribute getter (fix for issue 332)
# --> 836         return object.__getattribute__(self, name)
#     837
#     838     @property
#
# AttributeError: 'FileDataset' object has no attribute 'header'
